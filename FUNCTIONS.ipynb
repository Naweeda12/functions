# %% [markdown]
# #FUCTIONS
# 1- WHAT IS THE DIFF BETWEEB FUCTION AND PYTON?
#
#   -ANS-SO LETS ME JUST TAKE ME OUT.
#
# 2-WHAT IS YOUR NAME ?
#   - ANS-

# %% [markdown]
# 2- WJAT WUOALL AGAHT?
#    - ANS-

# %%
#WGAYB IS THE SRJ
RVDDX
HGGFCH
GGCGCN
GBHF
'''RGDEFHHH'''
GTTFT'''RDTE'''
GGCJ
GFGU
